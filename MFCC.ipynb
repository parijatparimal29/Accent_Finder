# %%
import librosa
import librosa.display

# %%
filename = "FR-F-1-9.wav"
y, sr = librosa.load(filename)

# %%
mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
img = librosa.display.specshow(mfccs, x_axis='time', ax=ax)
fig.colorbar(img, ax=ax)
ax.set(title='MFCC')
# Out:
# [Text(0.5, 1.0, 'MFCC')]

# %%
librosa.display.waveplot(mfccs,sr)
# Out:
# /Users/parijatparimal/opt/anaconda3/lib/python3.8/site-packages/librosa/util/utils.py:198: UserWarning: librosa.util.frame called with axis=-1 on a non-contiguous input. This will result in a copy.
#   warnings.warn(

# %%
import statistics as stats
plt.figure(figsize=(14, 5))
mfcc = []
for m in mfccs:
    mfcc.append(stats.mean(m))
plt.plot(mfcc)
plt.grid()
print(mfcc)
# Out:
# [-446.17203, 86.41362, -37.32707, 22.530045, -27.792871, -1.7407547, -13.667137, -4.578425, -2.7285383, 2.6576104, -6.145138, -4.5462, -9.028603]
